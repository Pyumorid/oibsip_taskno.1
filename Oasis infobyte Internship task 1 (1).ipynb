# %% [markdown]
# # Iris Flower Classification

# %%
#import the required libraries
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
iris_df=pd.read_csv("C:\\Users\\91915\\Downloads\\Iris Flower Classification.csv")
iris_df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_df.shape
# Out:
# (150, 6)

# %%
iris_df.info
# Out:
# <bound method DataFrame.info of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
iris_df.nunique
# Out:
# <bound method DataFrame.nunique of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
iris_df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
#change the name of column 
iris_df.columns=['id','sepallength','sepalwidth','petalleagth','petalwidth','species']

# %%
#null values in data set
iris_df.isnull().sum()
# Out:
# id             0
# sepallength    0
# sepalwidth     0
# petalleagth    0
# petalwidth     0
# species        0
# dtype: int64

# %%
iris_df.describe()
# Out:
#                id  sepallength  sepalwidth  petalleagth  petalwidth
# count  150.000000   150.000000  150.000000   150.000000  150.000000
# mean    75.500000     5.843333    3.054000     3.758667    1.198667
# std     43.445368     0.828066    0.433594     1.764420    0.763161
# min      1.000000     4.300000    2.000000     1.000000    0.100000
# 25%     38.250000     5.100000    2.800000     1.600000    0.300000
# 50%     75.500000     5.800000    3.000000     4.350000    1.300000
# 75%    112.750000     6.400000    3.300000     5.100000    1.800000
# max    150.000000     7.900000    4.400000     6.900000    2.500000

# %%
iris_df["species"].unique
# Out:
# <bound method Series.unique of 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: species, Length: 150, dtype: object>

# %%
iris_df.groupby("species").size()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
iris_counts=iris_df['species'].value_counts()
print("count of the species column")
print(iris_counts)
# Out:
# count of the species column
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
iris_counts=iris_df['petalwidth'].value_counts()
print("count of  petalwidth column")
print(iris_counts)
# Out:
# count of  petalwidth column
# 0.2    28
# 1.3    13
# 1.8    12
# 1.5    12
# 1.4     8
# 2.3     8
# 1.0     7
# 0.4     7
# 0.3     7
# 0.1     6
# 2.1     6
# 2.0     6
# 1.2     5
# 1.9     5
# 1.6     4
# 2.5     3
# 2.2     3
# 2.4     3
# 1.1     3
# 1.7     2
# 0.6     1
# 0.5     1
# Name: petalwidth, dtype: int64

# %%
iris_counts=iris_df['petalleagth'].value_counts()
print("count of  petalleagth column")
print(iris_counts)
# Out:
# count of  petalleagth column
# 1.5    14
# 1.4    12
# 5.1     8
# 4.5     8
# 1.6     7
# 1.3     7
# 5.6     6
# 4.7     5
# 4.9     5
# 4.0     5
# 4.2     4
# 5.0     4
# 4.4     4
# 4.8     4
# 1.7     4
# 3.9     3
# 4.6     3
# 5.7     3
# 4.1     3
# 5.5     3
# 6.1     3
# 5.8     3
# 3.3     2
# 5.4     2
# 6.7     2
# 5.3     2
# 5.9     2
# 6.0     2
# 1.2     2
# 4.3     2
# 1.9     2
# 3.5     2
# 5.2     2
# 3.0     1
# 1.1     1
# 3.7     1
# 3.8     1
# 6.6     1
# 6.3     1
# 1.0     1
# 6.9     1
# 3.6     1
# 6.4     1
# Name: petalleagth, dtype: int64

# %%
iris_counts=iris_df['sepallength'].value_counts()
print("count of  sepallength column")
print(iris_counts)
# Out:
# count of  sepallength column
# 5.0    10
# 5.1     9
# 6.3     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 4.9     6
# 5.4     6
# 6.1     6
# 6.0     6
# 5.6     6
# 4.8     5
# 6.5     5
# 6.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 5.9     3
# 4.4     3
# 7.2     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 7.3     1
# 7.0     1
# 7.1     1
# 5.3     1
# 4.3     1
# 4.5     1
# 7.9     1
# Name: sepallength, dtype: int64

# %%
iris_counts=iris_df['sepalwidth'].value_counts()
print("count of  sepalwidth column")
print(iris_counts)
# Out:
# count of  sepalwidth column
# 3.0    26
# 2.8    14
# 3.2    13
# 3.1    12
# 3.4    12
# 2.9    10
# 2.7     9
# 2.5     8
# 3.5     6
# 3.3     6
# 3.8     6
# 2.6     5
# 2.3     4
# 3.7     3
# 2.4     3
# 2.2     3
# 3.6     3
# 3.9     2
# 4.4     1
# 4.0     1
# 4.1     1
# 4.2     1
# 2.0     1
# Name: sepalwidth, dtype: int64

# %%
iris_counts=iris_df['id'].value_counts()
print("id")
print(iris_counts)
# Out:
# id
# 1      1
# 95     1
# 97     1
# 98     1
# 99     1
#       ..
# 51     1
# 52     1
# 53     1
# 54     1
# 150    1
# Name: id, Length: 150, dtype: int64

# %%
iris_df.head()
# Out:
#    id  sepallength  sepalwidth  petalleagth  petalwidth      species
# 0   1          5.1         3.5          1.4         0.2  Iris-setosa
# 1   2          4.9         3.0          1.4         0.2  Iris-setosa
# 2   3          4.7         3.2          1.3         0.2  Iris-setosa
# 3   4          4.6         3.1          1.5         0.2  Iris-setosa
# 4   5          5.0         3.6          1.4         0.2  Iris-setosa

# %%
#correlation diagram 
corr = iris_df.corr()
plt.subplots(figsize=(5,5))
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data=iris_df,hue='species',size=5)
# Out:
# D:\anaconda\lib\site-packages\seaborn\axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.countplot(data=iris_df,x='species',ec='green')
plt.xlabel("Name of species")
plt.ylabel("count")
plt.grid(True)
plt.show()

# %%
plt.bar(iris_df['species'],iris_df['petalleagth'])
plt.title("petal Length vs species")
plt.xlabel("name of the species")
plt.ylabel("Petal Length")
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, mean_absolute_error, mean_squared_error, r2_score 
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

# %%
X=iris_df.drop('species',axis=1)

# %%
X.head()
# Out:
#    id  sepallength  sepalwidth  petalleagth  petalwidth
# 0   1          5.1         3.5          1.4         0.2
# 1   2          4.9         3.0          1.4         0.2
# 2   3          4.7         3.2          1.3         0.2
# 3   4          4.6         3.1          1.5         0.2
# 4   5          5.0         3.6          1.4         0.2

# %%
Y=iris_df['species']

# %%
Y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: species, Length: 150, dtype: object

# %%
X
# Out:
#       id  sepallength  sepalwidth  petalleagth  petalwidth
# 0      1          5.1         3.5          1.4         0.2
# 1      2          4.9         3.0          1.4         0.2
# 2      3          4.7         3.2          1.3         0.2
# 3      4          4.6         3.1          1.5         0.2
# 4      5          5.0         3.6          1.4         0.2
# ..   ...          ...         ...          ...         ...
# 145  146          6.7         3.0          5.2         2.3
# 146  147          6.3         2.5          5.0         1.9
# 147  148          6.5         3.0          5.2         2.0
# 148  149          6.2         3.4          5.4         2.3
# 149  150          5.9         3.0          5.1         1.8
#
# [150 rows x 5 columns]

# %%
Y
# Out:
#       id  sepallength  sepalwidth  petalleagth  petalwidth
# 0      1          5.1         3.5          1.4         0.2
# 1      2          4.9         3.0          1.4         0.2
# 2      3          4.7         3.2          1.3         0.2
# 3      4          4.6         3.1          1.5         0.2
# 4      5          5.0         3.6          1.4         0.2
# ..   ...          ...         ...          ...         ...
# 145  146          6.7         3.0          5.2         2.3
# 146  147          6.3         2.5          5.0         1.9
# 147  148          6.5         3.0          5.2         2.0
# 148  149          6.2         3.4          5.4         2.3
# 149  150          5.9         3.0          5.1         1.8
#
# [150 rows x 5 columns]

# %%
#split the data into training and testing sets 
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.24,random_state=20)

# %%
X_train.head()
# Out:
#       id  sepallength  sepalwidth  petalleagth  petalwidth
# 85    86          6.0         3.4          4.5         1.6
# 1      2          4.9         3.0          1.4         0.2
# 51    52          6.4         3.2          4.5         1.5
# 130  131          7.4         2.8          6.1         1.9
# 55    56          5.7         2.8          4.5         1.3

# %%
X_train.shape
# Out:
# (114, 5)

# %%
X_test.head
# Out:
# <bound method NDFrame.head of       id  sepallength  sepalwidth  petalleagth  petalwidth
# 47    48          4.6         3.2          1.4         0.2
# 73    74          6.1         2.8          4.7         1.2
# 74    75          6.4         2.9          4.3         1.3
# 129  130          7.2         3.0          5.8         1.6
# 67    68          5.8         2.7          4.1         1.0
# 89    90          5.5         2.5          4.0         1.3
# 143  144          6.8         3.2          5.9         2.3
# 21    22          5.1         3.7          1.5         0.4
# 108  109          6.7         2.5          5.8         1.8
# 12    13          4.8         3.0          1.4         0.1
# 147  148          6.5         3.0          5.2         2.0
# 76    77          6.8         2.8          4.8         1.4
# 119  120          6.0         2.2          5.0         1.5
# 35    36          5.0         3.2          1.2         0.2
# ...

# %%
X_test.shape
# Out:
# (36, 5)

# %%
Y_train.head()
# Out:
# 85     Iris-versicolor
# 1          Iris-setosa
# 51     Iris-versicolor
# 130     Iris-virginica
# 55     Iris-versicolor
# Name: species, dtype: object

# %%
Y_train.shape
# Out:
# (114,)

# %%
Y_test.head()
# Out:
# 47         Iris-setosa
# 73     Iris-versicolor
# 74     Iris-versicolor
# 129     Iris-virginica
# 67     Iris-versicolor
# Name: species, dtype: object

# %%
Y_test.shape
# Out:
# (36,)

# %%
model=LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# D:\anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
#prediction
y_pred=model.predict(X_train)

# %%
y_pred
# Out:
# array(['Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
# ...

# %%
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica'],
#       dtype=object)

# %%
train_accuracy_score=model.score(X_train,Y_train)

# %%
print("training accuracy is",train_accuracy_score)
# Out:
# training accuracy is 0.9912280701754386

# %%
test_accuracy_score=model.score(X_test,Y_test)

# %%
print("training accuracy is",test_accuracy_score)
# Out:
# training accuracy is 0.9722222222222222
